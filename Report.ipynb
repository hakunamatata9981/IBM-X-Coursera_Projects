# %% [markdown]
# #### This project is going to analyze if the venues in the neighborhood have influence on property price in Manhattan, the result is shown below:

# %% [markdown]
# ![Screen%20Shot%202020-12-24%20at%206.28.41%20PM.png](attachment:Screen%20Shot%202020-12-24%20at%206.28.41%20PM.png)

# %% [markdown]
# ![Screen%20Shot%202020-12-24%20at%206.29.46%20PM.png](attachment:Screen%20Shot%202020-12-24%20at%206.29.46%20PM.png)

# %% [markdown]
# From the map and table above, we can see that cluster is pretty good at using venuees to differentiate neighborhood, it precisely point out roosevelt_island as cluster 1, and is one and only cluster in the table. From the table we can approximately tell that those with cluster 0, have an in average higher house price, lets print out more table and see.

# %% [markdown]
# ![Screen%20Shot%202020-12-24%20at%206.44.29%20PM.png](attachment:Screen%20Shot%202020-12-24%20at%206.44.29%20PM.png)

# %% [markdown]
# We can see from the table above that the average house price is the highest in cluster 0, lets see what is the top venues in these neighborhoods.

# %% [markdown]
# ![Screen%20Shot%202020-12-24%20at%206.50.20%20PM.png](attachment:Screen%20Shot%202020-12-24%20at%206.50.20%20PM.png)

# %% [markdown]
# ![Screen%20Shot%202020-12-24%20at%206.50.45%20PM.png](attachment:Screen%20Shot%202020-12-24%20at%206.50.45%20PM.png)

# %% [markdown]
# ![Screen%20Shot%202020-12-24%20at%206.51.19%20PM.png](attachment:Screen%20Shot%202020-12-24%20at%206.51.19%20PM.png)

# %% [markdown]
# ![Screen%20Shot%202020-12-24%20at%206.51.47%20PM.png](attachment:Screen%20Shot%202020-12-24%20at%206.51.47%20PM.png)

# %% [markdown]
# We can see in cluster 0, which the house price is the highest, the venues in the area is the most diverse, from spa, boutique to hotel. Compare this with cluster 3, which have the lowest average house price, the venues are mostly restaurant.

# %% [markdown]
# #### Conclusion:
#
# We can see that venues have some impact on house price, though it is not a causation, but there might have some correlation involved.
#
# What can be do in future research:
# Finding more sample, eg: entire NYC, and set a house price label from 1-5 based on neighborhood average price, than do some classification training on the venues to see what is the accuracy score.
#
# Maybe adding more features such as year the building is built, house type(condo, coop or house)....etc, to see if we can improve the accuracy score of these clustering model.
